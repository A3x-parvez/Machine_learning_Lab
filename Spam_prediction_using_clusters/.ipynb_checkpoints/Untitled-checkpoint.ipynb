# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder

# %%
# df = pd.read_csv('spam.csv', encoding='ISO-8859-1')
df = pd.read_csv('spam.csv', encoding='latin1')

# %%
df.sample(10)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 2678   ham  Was playng 9 doors game and gt racing on phone...        NaN
# 1737   ham  I cant pick the phone right now. Pls send a me...        NaN
# 2513  spam  U have won a nokia 6230 plus a free digital ca...        NaN
# 4596   ham             Full heat pa:-) i have applyed oil pa.        NaN
# 1118   ham  I'm going 4 lunch now wif my family then aft d...        NaN
# 4735   ham   Not for possession, especially not first offense        NaN
# 989    ham  Ugh. Gotta drive back to sd from la. My butt i...        NaN
# 2933   ham    Yup n her fren lor. I'm meeting my fren at 730.        NaN
# 3599   ham                          I know you mood off today        NaN
# 5034   ham  How many times i told in the stage all use to ...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 2678        NaN        NaN
# 1737        NaN        NaN
# 2513        NaN        NaN
# 4596        NaN        NaN
# 1118        NaN        NaN
# 4735        NaN        NaN
# 989         NaN        NaN
# 2933        NaN        NaN
# 3599        NaN        NaN
# 5034        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.isnull().mean()
# Out:
# v1            0.000000
# v2            0.000000
# Unnamed: 2    0.991027
# Unnamed: 3    0.997846
# Unnamed: 4    0.998923
# dtype: float64

# %%
df = df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'])

# %% [markdown]
# # Remove unwanted symbols using regex

# %%
# Function to clean text (keep only words)
def clean_text(text):
    text = re.sub(r'[^A-Za-z]', ' ', text)  # Remove everything except letters
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text.lower()  # Convert to lowercase

# Apply cleaning function to messages
df['v2'] = df['v2'].apply(clean_text)

# %%
df.sample(20)
# Out:
#         v1                                                 v2
# 2569   ham            ultimately tor motive tui achieve korli
# 5330   ham      dude im no longer a pisces im an aquarius now
# 5370  spam  dating i have had two of these only started af...
# 1001  spam  please call our customer service representativ...
# 2658   ham                           not yet chikku wat abt u
# 3827   ham  where are you what are you doing are yuou work...
# 1539   ham  you re not sure that i m not trying to make xa...
# 1425   ham                i ll be at mu in like lt gt seconds
# 1083   ham  wat makes some people dearer is not just de ha...
# 2458   ham             cool i ll text you when i m on the way
# 1138   ham                                     what u wearing
# 2941   ham  hello no news on job they are making me wait a...
# 3496   ham  oh the grand is having a bit of a party but it...
# 2779   ham                         well i might not come then
# 753    ham                    when did you get to the library
# 2368   ham            if you r home then come down within min
# 3768   ham  was gr to see that message so when r u leaving...
# 5444   ham  good morning at the repair shop the only reaso...
# 3291   ham             dear good morning how you feeling dear
# 157    ham  hello my love what are you doing did you get t...

# %% [markdown]
# # Remove Stopwords using nltk

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Download stopwords if not available
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\parvez\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Function to remove stopwords
def remove_stopwords(text):
    words = text.split()  # Tokenize (split into words)
    words = [word for word in words if word not in stop_words]  # Remove stopwords
    return ' '.join(words)  # Join back into a single string

# %%
# Apply cleaning function to messages
df['v2'] = df['v2'].apply(remove_stopwords)

# %%
df['v1'].value_counts()
# Out:
# v1
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
X = df['v2']
y = df['v1']

# %%
X.sample(10)
# Out:
# 1660                                   send bec temple na
# 4865    oh shit thought trip loooooool makes much sens...
# 3107    hello hun ru way im good dates guy met walkabo...
# 1229                              jus ans lar u noe later
# 4359    night sweet sleep well see exorcism emily rose...
# 3302                                                tough
# 4214                                      dear sleeping p
# 444     hey hey werethe monkeespeople say monkeyaround...
# 3537    pleased inform application airtel broadband pr...
# 2858    know god created gap fingers one made comes am...
# Name: v2, dtype: object

# %% [markdown]
# # Use CountVectorizer to convert the mail into vectors

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer()

# %%
': 5966, 'ffffffffff': 2251, 'alright': 193, 'meet': 3959, 'sooner': 6023, 'forced': 2385, 'eat': 1911, 'slice': 5918, 'really': 5245, 'hungry': 3032, 'tho': 6611, 'sucks': 6310, 'mark': 3889, 'getting': 2579, 'worried': 7380, 'knows': 3475, 'sick': 5837, 'turn': 6845, 'pizza': 4826, 'lol': 3715, 'always': 202, 'convincing': 1349, 'catch': 997, 'bus': 884, 'frying': 2475, 'egg': 1944, 'tea': 6483, 'eating': 1914, 'mom': 4112, 'left': 3585, 'dinner': 1709, 'love': 3759, 'amp': 220, 'packing': 4625, 'car': 959, 'let': 3607, 'know': 3472, 'room': 5478, 'ahhh': 139, 'work': 7370, 'vaguely': 7014, 'wait': 7126, 'clear': 1170, 'sure': 6364, 'sarcastic': 5575, 'live': 3680, 'us': 6984, 'yeah': 7475, 'apologetic': 289, 'fallen': 2186, 'actin': 60, 'spoilt': 6109, 'child': 1108, 'caught': 1001, 'till': 6653, 'badly': 494, 'cheers': 1084, 'tell': 6507, 'anything': 275, 'fear': 2224, 'fainti ...

# %%
X_vector = vectorizer.transform(X)

# %%
# Summarizing the Encoded Texts
print("Encoded Document is:")
print(X_vector.toarray().shape)
# Out:
# Encoded Document is:
# (5572, 7546)

# %%
# Encode 'ham' as 0 and 'spam' as 1
label_encoder = LabelEncoder()
y_enc = label_encoder.fit_transform(y)  # ham = 0, spam = 1

# %%
y_enc.shape
# Out:
# (5572,)

# %%
# Split into train and test sets before applying SMOTE
X_train, X_test, y_train, y_test = train_test_split(X_vector, y_enc, test_size=0.2, random_state=42, stratify=y_enc)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4457, 7546), (1115, 7546), (4457,), (1115,))

# %%
# Apply SMOTE to balance the classes
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
# # Convert back to DataFrame (optional)
# df_resampled = pd.DataFrame(X_train_resampled)
# df_resampled['v1'] = y_train_resampled

# %%
# Print new class distribution
print(pd.Series(y_train_resampled).value_counts())
# Out:
# 0    3859
# 1    3859
# Name: count, dtype: int64

# %%
# from imblearn.over_sampling import SMOTE

# smote = SMOTE(sampling_strategy='auto', random_state=42)
# X_resampled, y_resampled = smote.fit_resample(X.values.reshape(-1,1), y)

# df_resampled = pd.DataFrame({'v2': X_resampled.flatten(), 'v1': y_resampled})
# df_resampled['v1'].value_counts()

# %% [markdown]
# # Train Model

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
nb_model = MultinomialNB()
nb_model.fit(X_train_resampled, y_train_resampled)
# Out:
# MultinomialNB()

# %%
# Predict on test set
y_pred = nb_model.predict(X_test)
y_train_pred = nb_model.predict(X_train_resampled)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# # Test report and accuracy

# %%
# Evaluate model performance
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.4f}')

# Print classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Print confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.9650
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       966
#            1       0.84      0.91      0.87       149
#
#     accuracy                           0.97      1115
#    macro avg       0.91      0.94      0.93      1115
# weighted avg       0.97      0.97      0.97      1115
#
#
# Confusion Matrix:
# [[940  26]
#  [ 13 136]]

# %%
# Plot confusion matrix using seaborn heatmap
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap="Purples",linewidths=1, linecolor='black',
            xticklabels=['Not Spam', 'Spam'], 
            yticklabels=['Not Spam', 'Spam'])
plt.title('Confusion Matrix for Test')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# # Train Report and accuracy

# %%
accuracy = accuracy_score(y_train_resampled, y_train_pred)
print(f'Train Accuracy: {accuracy:.4f}')

# Print classification report
print("\nClassification Report:")
print(classification_report(y_train_resampled, y_train_pred))

# Print confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_train_resampled, y_train_pred))
# Out:
# Accuracy: 0.8939
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90      3859
#            1       0.98      0.81      0.88      3859
#
#     accuracy                           0.89      7718
#    macro avg       0.91      0.89      0.89      7718
# weighted avg       0.91      0.89      0.89      7718
#
#
# Confusion Matrix:
# [[3791   68]
#  [ 751 3108]]

# %%
# Plot confusion matrix using seaborn heatmap
cm_t = confusion_matrix(y_train_resampled, y_train_pred)
plt.figure(figsize=(10, 6))
sns.heatmap(cm_t, annot=True, fmt='d', cmap="Purples",linewidths=1, linecolor='black',
            xticklabels=['Not Spam', 'Spam'], 
            yticklabels=['Not Spam', 'Spam'])
plt.title('Confusion Matrix for Train')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
