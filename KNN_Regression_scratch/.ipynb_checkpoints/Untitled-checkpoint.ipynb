# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('placement.csv')

# %%
df.shape
# Out:
# (200, 2)

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
# Dataset
X = df['cgpa']
y = df['package']

# %%
# Out:
# 6.89

# %%
def KNN_reg(X,y,k=3):
    X_test = X
    # print(X_test)
    y_test = y
    # Distance and prediction
    for x in X_test:
        print("For ",x,"value")
        i=0
        print(x,"-",X_test[i])
        distances = np.sqrt(((X_test[i] - x)**2))
        print(distances)
        neighbors_idx = np.argsort(distances)[:k]
        avg = np.mean(y[neighbors_idx])
        # print(avg)
    #     r.append(avg)
    # print(neighbors_idx)
    # r = np.array(r)
    # print(r)

# %%
KNN_reg(X,y,k=3)
# Out:
# For  6.89 value
# 6.89 - 6.89
# 0.0
# For  5.12 value
# 5.12 - 6.89
# 1.7699999999999996
# For  7.82 value
# 7.82 - 6.89
# 0.9300000000000006
# For  7.42 value
# 7.42 - 6.89
# 0.5300000000000002
# For  6.94 value
# 6.94 - 6.89
# 0.05000000000000071
# For  7.89 value
# 7.89 - 6.89
# 1.0
# For  6.73 value
# 6.73 - 6.89
# 0.15999999999999925
# For  6.75 value
# 6.75 - 6.89
# 0.13999999999999968
# For  6.09 value
# 6.09 - 6.89
# 0.7999999999999998
# For  8.31 value
# 8.31 - 6.89
# 1.4200000000000008
# For  5.32 value
# 5.32 - 6.89
# 1.5699999999999994
# For  6.61 value
# 6.61 - 6.89
# 0.27999999999999936
# For  8.94 value
# 8.94 - 6.89
# 2.05
# For  6.93 value
# 6.93 - 6.89
# 0.040000000000000036
# For  7.73 value
# 7.73 - 6.89
# 0.8400000000000007
# For  7.25 value
# 7.25 - 6.89
# 0.3600000000000003
# For  6.84 value
# 6.84 - 6.89
# 0.04999999999999982
# For  5.38 value
# 5.38 - 6.89
# 1.5099999999999998
# For  6.94 value
# 6.94 - 6.89
# 0.05000000000000071
# For  7.48 value
# ...

# %%
import numpy as np

# Example data
X = np.array([[1], [2], [3], [4], [5]])  # Training data
x = np.array([2.5])  # Test point

# Calculate Euclidean distances
distances = np.sqrt(np.sum((X - x)**2, axis=1))

# Get the indices of the 3 smallest distances
k = 3
indices_of_min_distances = np.argsort(distances)[:k]

# Output the indices
print("Distances:", distances)
print("Indices of 3 nearest neighbors:", indices_of_min_distances)
